# %% [markdown]
# ## Ejercicios - Vídeo 4

# %%
import sqlalchemy
sqlalchemy.create_engine('mysql://scott:tiger@localhost/Curso_SQL')
# %load_ext sql
# %sql mysql://scott:tiger@localhost/Curso_SQL

# %% [markdown]
# 1. Realizar una consulta que muestre aquellos productos españoles cuya fecha esté comprendida entre febrero y mayo del 2002. Ordenar los resultados por el campo “Nombre artículo” descendentemente.

# %%
# %%sql
#
# SELECT *
# FROM PRODUCTOS
# WHERE PAÍSDEORIGEN = "España"and FECHA between '2002-02-1' and '2002-05-31'
# ORDER BY NOMBREARTÍCULO DESC
# Out:
#  * mysql://scott:***@localhost/Curso_SQL
# 3 rows affected.
# [('AR41', 'DEPORTES', 'PALAS DE PING PONG', Decimal('21.6000'), datetime.date(2002, 2, 2), 'FALSO', 'ESPAÑA', None),
#  ('AR37', 'CONFECCIÓN', 'CINTURÓN DE PIEL', Decimal('4.3273'), datetime.date(2002, 5, 12), 'FALSO', 'ESPAÑA', None),
#  ('AR40', 'DEPORTES', 'BOTA ALPINISMO', Decimal('144.0000'), datetime.date(2002, 5, 5), 'FALSO', 'ESPAÑA', None)]

# %% [markdown]
# 2. Realizar una consulta que muestre los campos “Empresa”, “Dirección” y “Población” de la tabla “Clientes”. Ordenar la consulta por el campo “Población” ascendentemente y por “Dirección” descendentemente

# %%
# %%sql
#
# SELECT EMPRESA, DIRECCIÓN, POBLACIÓN
# FROM CLIENTES
# ORDER BY POBLACIÓN, DIRECCIÓN DESC
# Out:
#  * mysql://scott:***@localhost/Curso_SQL
# 38 rows affected.
# [('CONFECCIONES ARTÍMEZ', 'GENERAL PERÓN 45', 'A CORUÑA'),
#  ('DEPORTES NAUTICOS GARCÍA', 'JUAN FERNÁNDEZ 89', 'ÁVILA'),
#  ('JUGUETES MARTÍNEZ', 'VIA LAYETANA 245', 'BARCELONA'),
#  ('JUGUETES EL BARATO', 'VÍA AUGUSTA 245', 'BARCELONA'),
#  ('JUGUETERÍA SUÁREZ', 'PARIS 123', 'BARCELONA'),
#  ('CONFECCIONES MÓNICA', 'MOTORES 67', 'BARCELONA'),
#  ('EL ESPAÑOLITO', 'MOTORES 34', 'BARCELONA'),
#  ('CONFECCIONES RUIZ', 'LLOBREGAT 345', 'BARCELONA'),
#  ('EXCLUSIVAS FERNÁNDEZ', 'LLOBREGAT 250', 'BARCELONA'),
#  ('BAZAR EL BARAT', 'DIAGONAL 56', 'BARCELONA'),
#  ('ALMACÉN POPULAR', 'LAS FUENTES 124', 'BILBAO'),
#  ('CONFECCIONES AMPARO', 'LOS MOROS 23', 'GIJÓN'),
#  ('CONFECCIONES HERMINIA', 'CORRIDA 345', 'GIJÓN'),
#  ('JUGUETES LA SONRISA', 'LA BAÑEZA 67', 'LEÓN'),
#  ('DEPORTES MORÁN', 'AUTONOMÍA 45', 'LUGO'),
#  ('FERRETERÍA LIMA', 'VALLECAS 45', 'MADRID'),
#  ('EXPORTASA', 'VALLECAS 34', 'MADRID'),
#  ('FERETERÍA EL CLAVO', 'PASEO DE ÁLAMOS 78', 'MADRID'),
#  ('EL PALACIO DE LA MODA', 'ORTEGA Y GASSET 129', 'MADRID'),
#  ('JUGUETES EDUCATIVOS SANZ', 'ORENSE 89', 'MADRID'),
#  ('FERRETERÍA LA ESCOBA', 'ORENSE 7', 'MADRID'),
#  ('BELTRÁN E HIJOS', 'LAS FUENTES 78', 'MADRID'),
#  ('DEPORTES GARCÍA', 'GUZMÁN EL BUENO 45', 'MADRID'),
#  ('CONFECCIONES GALÁN', 'FUENCARRAL 78', 'MADRID'),
#  ('BAZAR LA FARAONA', 'CASTILLA Y LEÓN 34', 'MADRID'),
#  ('BAZAR EL ARGENTINO', 'ATOCHA 55', 'MADRID'),
#  ('LA CASA DEL JUGUETE', 'AMÉRICA 45', 'MADRID'),
#  ('LA CURTIDORA', 'OLIVARES 3', 'MÁLAGA'),
#  ('LA MODERNA', 'LA PALOMA 123', 'OVIEDO'),
#  ('FERRETERÍA EL MARTILLO', 'CASTELLANOS 205', 'SALAMANCA'),
#  ('DEPORTES EL BRASILEÑO', 'ABEL MARTÍNEZ 67', 'SALAMANCA'),
#  ('FERNÁNDEZ SL', 'PASEO DEL MAR 45', 'SANTANDER'),
#  ('LÍNEA JOVEN', 'SIERPES 78', 'SEVILLA'),
#  ('SÁEZ Y CÍA', 'INFANTA MERCEDS 23', 'SEVILLA'),
#  ('ALMACENES FERNANDEZ', 'ANTÓN 67', 'TERUEL'),
#  ('BAZAR FRANCISCO', 'CARMEN 45', 'ZAMORA'),
#  ('LA TIENDA ELEGANTE', 'EL COMENDADOR 67', 'ZARAGOZA'),
#  ('DEPORTES EL MADRILEÑO', 'CASTILLA 345', 'ZARAGOZA')]

# %% [markdown]
# 3. Realizar una consulta que muestre todos los campos de la tabla “Clientes”. Ordenar los resultados por el campo “Población” ascendentemente

# %%
# %%sql
#
# SELECT *
# FROM CLIENTES
# ORDER BY POBLACIÓN
# Out:
#  * mysql://scott:***@localhost/Curso_SQL
# 38 rows affected.
# [('CT13', 'CONFECCIONES ARTÍMEZ', 'GENERAL PERÓN 45', 'A CORUÑA', 981345239, 'ESTEBAN PASCUAL', None),
#  ('CT32', 'DEPORTES NAUTICOS GARCÍA', 'JUAN FERNÁNDEZ 89', 'ÁVILA', 920268648, 'JUAN CONRADO', None),
#  ('CT33', 'CONFECCIONES RUIZ', 'LLOBREGAT 345', 'BARCELONA', 934587615, 'CARLOS SANZ', None),
#  ('CT27', 'JUGUETES EL BARATO', 'VÍA AUGUSTA 245', 'BARCELONA', 933486984, 'ELVIRA IGLESIAS', None),
#  ('CT22', 'BAZAR EL BARAT', 'DIAGONAL 56', 'BARCELONA', 936692866, 'ELISA DAPENA', None),
#  ('CT38', 'CONFECCIONES MÓNICA', 'MOTORES 67', 'BARCELONA', 935681245, 'PEDRO SERRANO', None),
#  ('CT15', 'EXCLUSIVAS FERNÁNDEZ', 'LLOBREGAT 250', 'BARCELONA', 939558365, 'LUISA FERNÁNDEZ', None),
#  ('CT11', 'JUGUETES MARTÍNEZ', 'VIA LAYETANA 245', 'BARCELONA', 936628554, 'FRANCISCO CUEVAS', None),
#  ('CT08', 'JUGUETERÍA SUÁREZ', 'PARIS 123', 'BARCELONA', 933457866, 'JUAN GARCÍA', None),
#  ('CT03', 'EL ESPAÑOLITO', 'MOTORES 34', 'BARCELONA', 934565343, 'ANA FERNÁNDEZ', None),
#  ('CT09', 'ALMACÉN POPULAR', 'LAS FUENTES 124', 'BILBAO', 942347127, 'JOSÉ ÁLVAREZ', None),
#  ('CT28', 'CONFECCIONES HERMINIA', 'CORRIDA 345', 'GIJÓN', 985597315, 'ABEL GONZÁLEZ', None),
#  ('CT06', 'CONFECCIONES AMPARO', 'LOS MOROS 23', 'GIJÓN', 985754332, 'LUÍS ÁLVAREZ', None),
#  ('CT18', 'JUGUETES LA SONRISA', 'LA BAÑEZA 67', 'LEÓN', 987945368, 'FAUSTINO PÉREZ', None),
#  ('CT16', 'DEPORTES MORÁN', 'AUTONOMÍA 45', 'LUGO', 982986944, 'JOSÉ MANZANO', None),
#  ('CT34', 'BAZAR LA FARAONA', 'CASTILLA Y LEÓN 34', 'MADRID', 915483627, 'ANGEL SANTAMARÍA', None),
#  ('CT26', 'FERRETERÍA LA ESCOBA', 'ORENSE 7', 'MADRID', 918459346, 'JOSÉ GARCÍA', None),
#  ('CT10', 'FERETERÍA EL CLAVO', 'PASEO DE ÁLAMOS 78', 'MADRID', 914354866, 'MANUEL MENÉNDEZ', None),
#  ('CT30', 'BAZAR EL ARGENTINO', 'ATOCHA 55', 'MADRID', 912495973, 'ADRIÁN ÁLVAREZ', None),
#  ('CT23', 'EL PALACIO DE LA MODA', 'ORTEGA Y GASSET 129', 'MADRID', 927785235, 'LAURA CARRASCO', None),
#  ('CT04', 'EXPORTASA', 'VALLECAS 34', 'MADRID', 913452378, 'ELVIRA GÓMEZ', None),
#  ('CT36', 'JUGUETES EDUCATIVOS SANZ', 'ORENSE 89', 'MADRID', 916872354, 'PEDRO IGLESIAS', None),
#  ('CT19', 'CONFECCIONES GALÁN', 'FUENCARRAL 78', 'MADRID', 913859234, 'JUAN GARCÍA', None),
#  ('CT07', 'LA CASA DEL JUGUETE', 'AMÉRICA 45', 'MADRID', 912649987, 'ELÍAS PÉREZ', None),
#  ('CT14', 'DEPORTES GARCÍA', 'GUZMÁN EL BUENO 45', 'MADRID', 913299475, 'ANA JIMÉNEZ', None),
#  ('CT39', 'FERRETERÍA LIMA', 'VALLECAS 45', 'MADRID', 913532785, 'LUIS GARCÍA', None),
#  ('CT01', 'BELTRÁN E HIJOS', 'LAS FUENTES 78', 'MADRID', 914456435, 'ANGEL MARTÍNEZ', None),
#  ('CT20', 'LA CURTIDORA', 'OLIVARES 3', 'MÁLAGA', 953756259, 'MARÍA GÓMEZ', None),
#  ('CT02', 'LA MODERNA', 'LA PALOMA 123', 'OVIEDO', 985323434, 'JUAN GARCÍA', None),
#  ('CT35', 'FERRETERÍA EL MARTILLO', 'CASTELLANOS 205', 'SALAMANCA', 923548965, 'JOAQUÍN FERNANDEZ', None),
#  ('CT40', 'DEPORTES EL BRASILEÑO', 'ABEL MARTÍNEZ 67', 'SALAMANCA', 921548762, 'CARLOS GÓMEZ', None),
#  ('CT12', 'FERNÁNDEZ SL', 'PASEO DEL MAR 45', 'SANTANDER', 942049586, 'ELISA COLLADO', None),
#  ('CT24', 'SÁEZ Y CÍA', 'INFANTA MERCEDS 23', 'SEVILLA', 954869234, 'MANUEL GUERRA', None),
#  ('CT21', 'LÍNEA JOVEN', 'SIERPES 78', 'SEVILLA', 953452567, 'ASUNCIÓN SALADO', None),
#  ('CT37', 'ALMACENES FERNANDEZ', 'ANTÓN 67', 'TERUEL', 978564025, 'MARIA ARDANZA', None),
#  ('CT17', 'BAZAR FRANCISCO', 'CARMEN 45', 'ZAMORA', 980495288, 'CARLOS BELTRÁN', None),
#  ('CT31', 'LA TIENDA ELEGANTE', 'EL COMENDADOR 67', 'ZARAGOZA', 975694035, 'JOSÉ PASCUAL', None),
#  ('CT25', 'DEPORTES EL MADRILEÑO', 'CASTILLA 345', 'ZARAGOZA', 976388934, 'CARLOS GONZÁLEZ', None)]
